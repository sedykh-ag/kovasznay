# %%
from utils_quantum import *
import pennylane as qml
import torch
from torch import nn
import matplotlib.pyplot as plt

# %%
circuit, weight_shapes, in_dim, out_dim = get_circuit(n_qubits=4, n_depth=4, n_layers=1)
draw_circuit(circuit, weight_shapes)

# %%
net = EncNet()
snapshot = torch.load("snapshots/ckpt.pt")
net.load_state_dict(snapshot["MODEL_STATE"])
# Out:
# <All keys matched successfully>

# %%
f = lambda x: 0.15 * torch.sin(x)
x = torch.linspace(-torch.pi, torch.pi, 100)

# %%
y_exact = f(x).flatten()
with torch.no_grad():
    y_pred = net(x).flatten()

# %%
plt.plot(x, y_exact)
plt.plot(x, y_pred)
